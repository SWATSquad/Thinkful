# %% [markdown]
# <a href="https://colab.research.google.com/github/SWATSquad/Thinkful/blob/main/Duplicates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

pathway = 'https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/training_classes_other.csv'

df = pd.read_csv(pathway)

#true or false
#df.isin([16, 8, 40])

#specific location
#df [df.isin([16, 8, 40])]

#counts per column
df.isin(['on-site']).sum()
# Out:
# Classes     0
# Hours       0
# Location    4
# Cost        0
# dtype: int64

# %%
df_prod = df
dict_items = {'Electronics':['earbuds','speakers'],'Cost':[25,75]}
df_prod.isin(dict_items)
# Out:
#    Classes  Hours  Location   Cost
# 0    False  False     False  False
# 1    False  False     False  False
# 2    False  False     False  False
# 3    False  False     False  False
# 4    False  False     False  False
# 5    False  False     False  False

# %% [markdown]
# isnull() / notnull()
# isna() / notna()

# %%
import pandas as pd
pathway = 'https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/training_classes_expanded.csv'
df2 = pd.read_csv(pathway)
#any() shows per column is null is true
#all() shows column with all NA / NULL
#sum() count nulls
df2.isnull().sum()
# Out:
# Classes      1
# Hours        1
# Location     2
# Cost         2
# Dates       15
# dtype: int64

# %%
#duplicated()
#duplicated(keep='last') (all last are false others are true)
#duplicated(keep=False) (all dups are true)
#df['Emp_ID'].duplicated() Identify duplicates specific colmn

df3 = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/emp_bonus.csv')
df3['Emp_ID'].duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# 9    False
# Name: Emp_ID, dtype: bool

# %%
#remove duplicates

df4 = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/emp_bonus.csv')
#df4a = df4.drop_duplicates()
df5 = df3
#df5.drop_duplicates(subset='Emp_ID', inplace=True)
#df5['Emp_ID'].drop_duplicates()
df5.drop_duplicates(subset='Emp_ID')
# Out:
#    Emp_ID Position Location  Bonus
# 0    1234      mgr     west   1000
# 1    1010      mgr     west    500
# 4    3535    staff     east    750
# 5    5678    staff     east   1200
# 9    8822    staff     west   1250
