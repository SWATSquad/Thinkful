# %% [markdown]
# <a href="https://colab.research.google.com/github/SWATSquad/Thinkful/blob/main/missing_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pathway = 'https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/product_information.csv'
df = pd.read_csv(pathway)
df
# Out:
#        prod_name  prod_qty  prod_price
# 0        headset      60.0           1
# 1       ear buds       NaN           0
# 2    USB adapter      50.0           5
# 3  charging cord       NaN           3
# 4     phone case      90.0           2
# 5        charger      70.0           3
# 6       car clip      80.0           1
# 7          stand       NaN           3
# 8   screen cover      50.0           0
# 9        lanyard      50.0           4

# %%
#remo NaN
df_drop_na = df.dropna()
df_drop_na
# Out:
#       prod_name  prod_qty  prod_price
# 0       headset      60.0           1
# 2   USB adapter      50.0           5
# 4    phone case      90.0           2
# 5       charger      70.0           3
# 6      car clip      80.0           1
# 8  screen cover      50.0           0
# 9       lanyard      50.0           4

# %%
df_replace_nan = df.fillna(60)
df_replace_nan
# Out:
#        prod_name  prod_qty  prod_price
# 0        headset      60.0           1
# 1       ear buds      60.0           0
# 2    USB adapter      50.0           5
# 3  charging cord      60.0           3
# 4     phone case      90.0           2
# 5        charger      70.0           3
# 6       car clip      80.0           1
# 7          stand      60.0           3
# 8   screen cover      50.0           0
# 9        lanyard      50.0           4

# %%
df['prod_qty'].median()
# Out:
# 60.0

# %%
#replace price 0 to
#pd['prod_price'].replace(0,5)
df_replace_nan.replace(0,2.5)
# Out:
#        prod_name  prod_qty  prod_price
# 0        headset      60.0         1.0
# 1       ear buds      60.0         2.5
# 2    USB adapter      50.0         5.0
# 3  charging cord      60.0         3.0
# 4     phone case      90.0         2.0
# 5        charger      70.0         3.0
# 6       car clip      80.0         1.0
# 7          stand      60.0         3.0
# 8   screen cover      50.0         2.5
# 9        lanyard      50.0         4.0

# %%
#interpolate(method = '')
#linear is avg
#pad is surrounding
df.interpolate(method = 'pad')
# Out:
#        prod_name  prod_qty  prod_price
# 0        headset      60.0           1
# 1       ear buds      60.0           0
# 2    USB adapter      50.0           5
# 3  charging cord      50.0           3
# 4     phone case      90.0           2
# 5        charger      70.0           3
# 6       car clip      80.0           1
# 7          stand      80.0           3
# 8   screen cover      50.0           0
# 9        lanyard      50.0           4
