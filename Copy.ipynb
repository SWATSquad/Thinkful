# %% [markdown]
# <a href="https://colab.research.google.com/github/SWATSquad/Thinkful/blob/main/Copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/loss_prevention_data.csv')

#iloc and loc (index location)
#df.iloc[[5]]
#df.iloc[[1,5]]
#df.iloc[[0,1,5],[0,2,3]]
df1 = df

reference_index = [3456,3457,3458,3459,3460,3461]
df1.index = reference_index
df.loc[[3457,3461], ['item','item_cost']]
# Out:
#             item  item_cost
# 3457       razor       4.92
# 3461  cell phone     399.99

# %% [markdown]
# 4.12.2

# %%
df01 = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/loss_prevention_data.csv')
df01
# Out:
#             item      item_dept  item_cost  num_thefts   date
# 0     cell phone    electronics     399.99           6  1-Jun
# 1          razor  personal care       4.92           2  1-Jun
# 2     cell phone    electronics     399.99           4  2-Jun
# 3  phone charger    electronics       6.99           1  2-Jun
# 4      sunscreen  personal care       7.98           1  3-Jun
# 5     cell phone    electronics     399.99           8  4-Jun

# %%
df_under = df['item_cost'] <= 10.00
df_over = df['item_cost'] > 10.00
df[df_under | df_over]
# Out:
#                item      item_dept  item_cost  num_thefts   date
# 3456     cell phone    electronics     399.99           6  1-Jun
# 3457          razor  personal care       4.92           2  1-Jun
# 3458     cell phone    electronics     399.99           4  2-Jun
# 3459  phone charger    electronics       6.99           1  2-Jun
# 3460      sunscreen  personal care       7.98           1  3-Jun
# 3461     cell phone    electronics     399.99           8  4-Jun

# %%
df_june = df['date'] == '2-Jun'
df_electronics = df['item_dept'] == 'electronics'
df[df_june & df_electronics]
# Out:
#                item    item_dept  item_cost  num_thefts   date
# 3458     cell phone  electronics     399.99           4  2-Jun
# 3459  phone charger  electronics       6.99           1  2-Jun

# %% [markdown]
# 4.12.3 COPY

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/holiday_shift_dataset.csv')
df_deepcopy = df.copy(deep=True)
df_copy = df.copy(deep=False)
df_deepcopy['num_employees'].replace(40,26, inplace=True)
df_deepcopy
# Out:
#      date  shift  num_employees  full_time_employees  part_time_employees  \
# 0  20-Nov    day             24                   20                    4
# 1  20-Nov  night             12                    6                    6
# 2  21-Nov    day             26                   24                    2
# 3  21-Nov  night             12                    6                    6
# 4  22-Nov    day             26                   40                    0
# 5  22-Nov  night             22                   14                    8
#
#    total_hours
# 0          176
# 1           72
# 2          200
# 3           72
# 4          320
# 5          232
