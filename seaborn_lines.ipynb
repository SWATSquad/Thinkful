# %% [markdown]
# <a href="https://colab.research.google.com/github/SWATSquad/Thinkful/blob/main/seaborn_lines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


_labels = df['store_loc']
df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/emp_avg_data.csv')
df
# Out:
#        store_loc  num_emp  avg_emp_tenure_in_years  avg_emp_rating  \
# 0        Atlanta       17                        1               3
# 1         Austin       12                        6               4
# 2        Chicago       22                        3               3
# 3         Denver       21                        5               4
# 4        Detroit       10                        1               2
# 5          Miami       30                        2               3
# 6       Portland       13                        4               4
# 7  San Francisco       20                        1               1
# 8        Seattle       25                       10               5
#
#   emp_break_room
# 0             No
# 1            Yes
# 2            Yes
# 3             No
# 4             No
# 5             No
# 6            Yes
# 7             No
# 8            Yes

# %%
sns.lineplot(x='avg_emp_rating', y='avg_emp_tenure_in_years', data=df)
sns.lineplot(x= 'avg_emp_rating', y= 'num_emp', data=df)
plt.xlabel('Rating')
plt.ylabel('Years')
plt.legend(labels=['AVG Employment Rating', 'AVG Tenure in Years','AVG Employment Rating', 'Number of Employees'])
plt.show()

# %%
dfTest = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/item_transactions.csv ')
sns.lineplot(x='month', y='qty', data=dfTest)
plt.xlabel('Months')
plt.ylabel('Quantity')
plt.legend(labels=['Quantity'])
plt.show()

# %%
df
# Out:
#   month  item_id  qty  discounts     status
# 0   Jan     3421    7          2  delivered
# 1   Feb     5251    5          4   returned
# 2   Mar     4321    4          5  delivered
# 3   Apr     6573    6          2  delivered
# 4   May     8732    2          3  delivered
# 5   Jun     2386    8          2   returned
# 6   Jul     1433    5          1  delivered
# 7   Aug     9823    9          0  delivered
# 8   Sep     7671   10          7   returned
# 9   Oct     2399    8          3  delivered

# %%
dfTest = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/item_transactions.csv ')
#sns.lineplot(x='month', y='qty', dashes=['status' == 'returned', dashes=['status' == 'delivered'], data=dfTest)
#sns.lineplot(x='month', y='qty', data=dfTest)
#sns.lineplot(y='month', x=dfTest.status=='returned', data=dfTest, ci=None), sns.lineplot(y='month', x=dfTest.status=='delivered', data=dfTest,ci=None)
#sns.lineplot(x='month', y='qty', data=dfTest, ci=None)
sns.lineplot(x='month', y=dfTest.status=='returned', data=dfTest, ci=None)
sns.lineplot(x='month', y=dfTest.status=='delivered', data=dfTest,ci=None)
plt.xlabel('Months')
plt.ylabel('Quantity')
plt.legend(labels=['Quantity returned','','Quantity delivered'])
plt.show()
# Out:
# <ipython-input-102-e4f513dc17a3>:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='month', y=dfTest.status=='returned', data=dfTest, ci=None)
# <ipython-input-102-e4f513dc17a3>:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='month', y=dfTest.status=='delivered', data=dfTest,ci=None)
